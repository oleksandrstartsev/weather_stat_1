# %%
#Plot linear regression lines for Kyiv temperatures for 1881-2020
#Regression was already performed in Analyses2 notebook
#Here we just visualize the data

'''

slope, intercept, r_value, p_value, std_err caclulated using scipy.stats.linregress

MIN = 5.842804217460086e-05, 2.64493410712056, 1.0, 0.0, 0.0
MEAN = 4.09814909717529e-05, 6.796480543505128, 1.0, 0.0, 0.0
MAX = 3.744083671349111e-05, 10.945711727842637, 1.0, 0.0, 0.0

'''
#Lets import libraries...
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

fig, ax = plt.subplots()
plt.title = "Average daily temperatures with time using linear regression"
plt.style_label="classic"

#preparing data
ex = np.linspace(0,50250, 52250)
ey_min = [ 5.842804217460086e-05*x + 2.64493410712056 for x in ex]
ey_mean =[ 4.09814909717529e-05*x + 6.796480543505128 for x in ex]
ey_max =[ 3.744083671349111e-05*x + 10.945711727842637  for x in ex]

line1, = ax.plot(ex, ey_max, label='T MAX linreg', color = 'red')
line2, = ax.plot(ex, ey_mean,  label='T MEAN linreg', color = "black")
line2, = ax.plot(ex, ey_min,  label='T MIN linreg', color = "blue")



labels = ['','1881', '1909', '1937', '1965', '1993','2020']

ax.set_xticklabels(labels)
ax.set_xlabel("Years")
ax.set_ylabel("T, °C")
ax.set_title("Evolution of temperatures with time from linear regression", y = 1.05)
ax.legend()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
